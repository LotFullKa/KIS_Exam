# %% [markdown]
# В силу ограниченного времени я реализую функции подразумевая, что они будут применяться условного к файлам с кодом. В файлах с кодом нет длинных строк (PEP8 не длиннеe 79 символов)
#
# Если эти функции применять к файлам с расширением, скажем, png, то код будет не эффективен.

# %%
import string
from time import time
import pickle as pck

# %% [markdown]
# Создадим отдельный класс для хранения строк отличия.
# В нем будем хранить строку, если она удалялась.
# Или координаты строк которые были добавлены.

# %%
class DiffString:
    def __init__(self,
                 begin_old: int, end_old: int,
                 begin_new: int, end_new: int,
                 deleted_str: string = ''):
        """Constructor"""
        self.begin_old = begin_old
        self.end_old = end_old
        self.begin_new = begin_new
        self.end_new = end_new
        self.deleted_str = deleted_str

# %% [markdown]
# Функция создает список объектов DiffString, в которых хранятся строки отличия между файдам old_file  и new_file

# %%
def GetDiffList(old_file, new_file):
    old_file_lines = [line for line in old_file]
    new_file_lines = [line for line in new_file]
    result = []

    last_checked_str = 0
    for k in range(len(old_file_lines)):

        next_bidder = -1
        go_next = True

        while go_next and (last_checked_str + next_bidder + 1 < len(new_file_lines)):
            next_bidder += 1
            if old_file_lines[k] == new_file_lines[last_checked_str + next_bidder]:
                go_next = False

        if go_next:
            result.append(DiffString(k, k, -1, -1, old_file_lines[k]))
        elif next_bidder == 0:
            last_checked_str += 1
        else:
            result.append(DiffString(-1, -1, last_checked_str, last_checked_str + next_bidder))
            last_checked_str = last_checked_str + next_bidder + 1

    return result

# %% [markdown]
# Публичная функция, которая создает diff файл с именем 'old_to_new_time'.
# Принимает на вход имена двух файлов, находящихся в той же директории, что и файл кода. Возращает имя diff файла.

# %%
def CalculateTheDiff(old: string, new: string):
    old_file = open(old, 'rb')
    new_file = open(new, 'rb')

    diff_file_name = old + '_to_' + new + '_' + str(time())
    diff_file = open(diff_file_name, 'wb')

    list_of_diff = GetDiffList(old_file, new_file)
    pck.dump(list_of_diff, diff_file)

    old_file.close()
    new_file.close()
    diff_file.close()

    return diff_file_name

# %% [markdown]
# Восстанавливает из "старого" файла новый по дифф файлу

# %%
def Restore(old_file: string, diff_file: string):
    old_file_fd = open(old_file, 'rb')
    old_file_lines = [line for line in old_file_fd]
    diff_file_fd = open(diff_file, 'rb')
    differences = pck.load(diff_file_fd)
    diff_file_fd.close()

    shift = 0

    for diff_line in differences:
        if diff_line.begin_old == -1:
            for i in range(diff_line.begin_new, diff_line.end_new):
                old_file_lines.pop(diff_line.begin_new + shift)
            shift -= (diff_line.end_new - diff_line.begin_new)
        else:
            old_file_lines.insert(diff_line.begin_old, diff_line.deleted_str)
            shift += 1

    old_file_fd.close()

    with open(old_file, 'wb') as answer:
        for line in old_file_lines:
            answer.write(line)

# %% [markdown]
# Пример выполнения:

# %%
print('ИСХОДНЫЙ ФАЙЛ')
print('-'*30)

with open('old', 'rb') as f:
  for line in f:
    print(line)
print('_'*30)

print('ИЗМЕНЕННЫЙ ФАЙЛ')
print('-'*30)
with open('new', 'rb') as f:
  for line in f:
    print(line)
# Out:
# ИСХОДНЫЙ ФАЙЛ
# ------------------------------
# b'import string\n'
# b'import abc\n'
# b'from collections import defaultdict\n'
# b'\n'
# b'from main.config import ALPHABET_POWER, ALPHABET_LETTER_CODE\n'
# b'from main.encode import CaesarEncoderDecoder\n'
# b'from main.train import DefaultTrainer\n'
# b'\n'
# b'\n'
# b'class Hacker:\n'
# b'    __metaclass__ = abc.ABCMeta\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        self.model = defaultdict(float, model)\n'
# b'\n'
# b'    @abc.abstractmethod\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        pass\n'
# b'\n'
# b'\n'
# b'class CaesarHacker(Hacker):\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        super().__init__(model)\n'
# b'        self.caesar_decoders = [CaesarEncoderDecoder(shift) for shift in range(ALPHABET_POWER)]\n'
# b'        self.trainer = DefaultTrainer()\n'
# b'\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        results = [0 for shift in range(ALPHABET_POWER)]\n'
# b'        shift_result = 0\n'
# b'\n'
# b'        self.trainer.feed(text)\n'
# b'        current_model = self.trainer.get_model()\n'
# b'        for shift in range(ALPHABET_POWER):\n'
# b'            for letter in string.ascii_lowercase:\n'
# b'                results[shift] += (self.model[letter] - current_model[letter]) ** 2\n'
# b'            if results[shift] < results[shift_result]:\n'
# b'                shift_result = shift\n'
# b'\n'
# b'            tmp = current_model[ALPHABET_POWER - 1]\n'
# b'            for letter_id in range(ALPHABET_POWER):\n'
# b'                current_model[string.ascii_lowercase[letter_id]] = current_model[\n'
# b'                    string.ascii_lowercase[(letter_id + 1) % ALPHABET_POWER]]\n'
# b'            current_model[0] = tmp\n'
# b'\n'
# b'        self.trainer.clear()\n'
# b'\n'
# b"        return self.caesar_decoders[shift_result].encode(text, 'decode')\n"
# b'\n'
# b'\n'
# b'class VigenereHacker(Hacker):\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        super().__init__(model)\n'
# b'        try:\n'
# b"            self.coincidence_index = self.model['coincidence_index']\n"
# b'        except KeyError:\n'
# b"            raise KeyError('Wrong model format')\n"
# b'\n'
# b'    def calc_coincidence_index(self, text: str):\n'
# b'        count = [0 for letter in range(ALPHABET_POWER)]\n'
# b'        sum_count = 0\n'
# b'\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b"                count[ALPHABET_LETTER_CODE[letter.lower()] - ALPHABET_LETTER_CODE['a']] += 1\n"
# b'                sum_count += 1\n'
# b'\n'
# b'        if sum_count <= 2:\n'
# b'            return 0\n'
# b'\n'
# b'import string\n'
# b'import abc\n'
# b'from collections import defaultdict\n'
# b'\n'
# b'from main.config import ALPHABET_POWER, ALPHABET_LETTER_CODE\n'
# b'from main.encode import CaesarEncoderDecoder\n'
# b'from main.train import DefaultTrainer\n'
# b'\n'
# b'\n'
# b'class Hacker:\n'
# b'    __metaclass__ = abc.ABCMeta\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        self.model = defaultdict(float, model)\n'
# b'\n'
# b'    @abc.abstractmethod\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        pass\n'
# b'\n'
# b'\n'
# b'class CaesarHacker(Hacker):\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        super().__init__(model)\n'
# b'        self.caesar_decoders = [CaesarEncoderDecoder(shift) for shift in range(ALPHABET_POWER)]\n'
# b'        self.trainer = DefaultTrainer()\n'
# b'\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        results = [0 for shift in range(ALPHABET_POWER)]\n'
# b'        shift_result = 0\n'
# b'\n'
# b'        self.trainer.feed(text)\n'
# b'        current_model = self.trainer.get_model()\n'
# b'        for shift in range(ALPHABET_POWER):\n'
# b'            for letter in string.ascii_lowercase:\n'
# b'                results[shift] += (self.model[letter] - current_model[letter]) ** 2\n'
# b'            if results[shift] < results[shift_result]:\n'
# b'                shift_result = shift\n'
# b'\n'
# b'            tmp = current_model[ALPHABET_POWER - 1]\n'
# b'            for letter_id in range(ALPHABET_POWER):\n'
# b'                current_model[string.ascii_lowercase[letter_id]] = current_model[\n'
# b'                    string.ascii_lowercase[(letter_id + 1) % ALPHABET_POWER]]\n'
# b'            current_model[0] = tmp\n'
# b'\n'
# b'        self.trainer.clear()\n'
# b'\n'
# b"        return self.caesar_decoders[shift_result].encode(text, 'decode')\n"
# b'\n'
# b'\n'
# b'class VigenereHacker(Hacker):\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        super().__init__(model)\n'
# b'        try:\n'
# b"            self.coincidence_index = self.model['coincidence_index']\n"
# b'        except KeyError:\n'
# b"            raise KeyError('Wrong model format')\n"
# b'\n'
# b'    def calc_coincidence_index(self, text: str):\n'
# b'        count = [0 for letter in range(ALPHABET_POWER)]\n'
# b'        sum_count = 0\n'
# b'\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b"                count[ALPHABET_LETTER_CODE[letter.lower()] - ALPHABET_LETTER_CODE['a']] += 1\n"
# b'                sum_count += 1\n'
# b'\n'
# b'        if sum_count <= 2:\n'
# b'            return 0\n'
# b'\n'
# b'        result = 0\n'
# b'        for letter in range(ALPHABET_POWER):\n'
# b'            result += (count[letter] * (count[letter] - 1)) / (sum_count * (sum_count - 1))\n'
# b'\n'
# b'        return result\n'
# b'\n'
# b'    def check_length(self, text: str, length: int):\n'
# b'        current_text = []\n'
# b'        for position in range(0, len(text), length):\n'
# b'            current_text.append(text[position])\n'
# b"        return self.calc_coincidence_index(''.join(current_text))\n"
# b'\n'
# b'    def calc_key_len(self, len_ic: list):\n'
# b'        key_len = 1\n'
# b'        for length, coincidence_index in enumerate(len_ic):\n'
# b'            if self.coincidence_index < coincidence_index:\n'
# b'                key_len = length + 1\n'
# b'                break\n'
# b'            if abs(coincidence_index - self.coincidence_index) < abs(len_ic[key_len - 1] - self.coincidence_index):\n'
# b'                key_len = length + 1\n'
# b'        return key_len\n'
# b'\n'
# b'    def calc_result(self, text: str, key_len: int, strings: list):\n'
# b'        result = []\n'
# b'\n'
# b'        letter_id = 0\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b'                symbol = strings[letter_id % key_len][letter_id // key_len]\n'
# b'                if letter.isupper():\n'
# b'                    symbol = symbol.upper()\n'
# b'                result.append(symbol)\n'
# b'                letter_id += 1\n'
# b'            else:\n'
# b'                result.append(letter)\n'
# b'        return result\n'
# b'\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        letters = []\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b'                letters.append(letter.lower())\n'
# b'\n'
# b"        letter_text = ''.join(letters)\n"
# b'\n'
# b'        len_ic = []\n'
# b'        current_length = 1\n'
# b'        while current_length * current_length < len(letter_text):\n'
# b'            len_ic.append(self.check_length(letter_text, current_length))\n'
# b'            current_length += 1\n'
# b'\n'
# b'        key_len = self.calc_key_len(len_ic)\n'
# b'\n'
# b"        strings = ['' for index in range(key_len)]\n"
# b'        for position, symbol in enumerate(letter_text):\n'
# b"            strings[position % key_len] = ''.join((strings[position % key_len],  symbol))\n"
# b'\n'
# b'        caesar_hacker = CaesarHacker(self.model)\n'
# b'        for index in range(key_len):\n'
# b'            strings[index] = caesar_hacker.hack(strings[index])\n'
# b'\n'
# b'        result = self.calc_result(text, key_len, strings)\n'
# b'\n'
# b"        return ''.join(result)"
# ______________________________
# ИЗМЕНЕННЫЙ ФАЙЛ
# ------------------------------
# b'import string\n'
# b'import abc\n'
# b'from collections import defaultdict\n'
# b'\n'
# b'from main.config import ALPHABET_POWER, ALPHABET_LETTER_CODE\n'
# b'from main.encode import CaesarEncoderDecoder\n'
# b'from main.train import DefaultTrainer\n'
# b'\n'
# b'\n'
# b'class Hacker:\n'
# b'    __metaclass__ = abc.ABCMeta\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        self.model = defaultdict(float, model)\n'
# b'\n'
# b'    @abc.abstractmethod\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        pass\n'
# b'\n'
# b'\n'
# b'class CaesarHacker(Hacker):\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        super().__init__(model)\n'
# b'        self.caesar_decoders = [CaesarEncoderDecoder(shift) for shift in range(ALPHABET_POWER)]\n'
# b'        self.trainer = DefaultTrainer()\n'
# b'\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        results = [0 for shift in range(ALPHABET_POWER)]\n'
# b'        shift_result = 0\n'
# b'\n'
# b'        self.trainer.feed(text)\n'
# b'        current_model = self.trainer.get_model()\n'
# b'        for shift in range(ALPHABET_POWER):\n'
# b'            for letter in string.ascii_lowercase:\n'
# b'                results[shift] += (self.model[letter] - current_model[letter]) ** 2\n'
# b'            if results[shift] < results[shift_result]:\n'
# b'                shift_result = shift\n'
# b'\n'
# b'            tmp = current_model[ALPHABET_POWER - 1]\n'
# b'            for letter_id in range(ALPHABET_POWER):\n'
# b'                current_model[string.ascii_lowercase[letter_id]] = current_model[\n'
# b'                    string.ascii_lowercase[(letter_id + 1) % ALPHABET_POWER]]\n'
# b'            current_model[0] = tmp\n'
# b'\n'
# b'        self.trainer.clear()\n'
# b'\n'
# b"        return self.caesar_decoders[shift_result].encode(text, 'decode')\n"
# b'\n'
# b'\n'
# b'class VigenereHacker(Hacker):\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        super().__init__(model)\n'
# b'        try:\n'
# b"            self.coincidence_index = self.model['coincidence_index']\n"
# b'        except KeyError:\n'
# b"            raise KeyError('Wrong model format')\n"
# b'\n'
# b'    def calc_coincidence_index(self, text: str):\n'
# b'        count = [0 for letter in range(ALPHABET_POWER)]\n'
# b'        sum_count = 0\n'
# b'\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b"                count[ALPHABET_LETTER_CODE[letter.lower()] - ALPHABET_LETTER_CODE['a']] += 1\n"
# b'                sum_count += 1\n'
# b'\n'
# b'        if sum_count <= 2:\n'
# b'            return 0\n'
# b'\n'
# b'import string\n'
# b'import abc\n'
# b'from collections import defaultdict\n'
# b'\n'
# b'from main.config import ALPHABET_POWER, ALPHABET_LETTER_CODE\n'
# b'from main.encode import CaesarEncoderDecoder\n'
# b'from main.train import DefaultTrainer\n'
# b'\n'
# b'\n'
# b'class Hacker:\n'
# b'    __metaclass__ = abc.ABCMeta\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        self.model = defaultdict(float, model)\n'
# b'\n'
# b'    @abc.abstractmethod\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        pass\n'
# b'\n'
# b'class VigenereHacker(Hacker):\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        super().__init__(model)\n'
# b'        try:\n'
# b"            self.coincidence_index = self.model['coincidence_index']\n"
# b'        except KeyError:\n'
# b"            raise KeyError('Wrong model format')\n"
# b'\n'
# b'    def calc_coincidence_index(self, text: str):\n'
# b'        count = [0 for letter in range(ALPHABET_POWER)]\n'
# b'        sum_count = 0\n'
# b'\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b"                count[ALPHABET_LETTER_CODE[letter.lower()] - ALPHABET_LETTER_CODE['a']] += 1\n"
# b'                sum_count += 1\n'
# b'\n'
# b'        if sum_count <= 2:\n'
# b'            return 0\n'
# b'\n'
# b'        result = 0\n'
# b'        for letter in range(ALPHABET_POWER):\n'
# b'            result += (count[letter] * (count[letter] - 1)) / (sum_count * (sum_count - 1))\n'
# b'\n'
# b'        return result\n'
# b'\n'
# b'    def check_length(self, text: str, length: int):\n'
# b'        current_text = []\n'
# b'        for position in range(0, len(text), length):\n'
# b'            current_text.append(text[position])\n'
# b"        return self.calc_coincidence_index(''.join(current_text))\n"
# b'\n'
# b'    def calc_key_len(self, len_ic: list):\n'
# b'        key_len = 1\n'
# b'        for length, coincidence_index in enumerate(len_ic):\n'
# b'            if self.coincidence_index < coincidence_index:\n'
# b'                key_len = length + 1\n'
# b'                break\n'
# b'            if abs(coincidence_index - self.coincidence_index) < abs(len_ic[key_len - 1] - self.coincidence_index):\n'
# b'                key_len = length + 1\n'
# b'        return key_len\n'
# b'\n'
# b'    def calc_result(self, text: str, key_len: int, strings: list):\n'
# b'        result = []\n'
# b'\n'
# b'        letter_id = 0\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b'                symbol = strings[letter_id % key_len][letter_id // key_len]\n'
# b'                if letter.isupper():\n'
# b'                    symbol = symbol.upper()\n'
# b'                result.append(symbol)\n'
# b'                letter_id += 1\n'
# b'            else:\n'
# b'                result.append(letter)\n'
# b'        return result\n'
# b'\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        letters = []\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b'                letters.append(letter.lower())\n'
# b'\n'
# b"        letter_text = ''.join(letters)\n"
# b'\n'
# b'        len_ic = []\n'
# b'        current_length = 1\n'
# b'        while current_length * current_length < len(letter_text):\n'
# b'            len_ic.append(self.check_length(letter_text, current_length))\n'
# b'            current_length += 1\n'
# b'\n'
# b'        key_len = self.calc_key_len(len_ic)\n'
# b'\n'
# b"        strings = ['' for index in range(key_len)]\n"
# b'        for position, symbol in enumerate(letter_text):\n'
# b"            strings[position % key_len] = ''.join((strings[position % key_len],  symbol))\n"
# b'\n'
# b'        caesar_hacker = CaesarHacker(self.model)\n'
# b'        for index in range(key_len):\n'
# b'            strings[index] = caesar_hacker.hack(strings[index])\n'
# b'\n'
# b'        result = self.calc_result(text, key_len, strings)\n'
# b'\n'
# b"        return ''.join(result)"

# %%
name = CalculateTheDiff('old', 'new')
Restore('new', name)

# %%
print('ИСХОДНЫЙ ФАЙЛ')
print('-'*30)

with open('old', 'rb') as f:
  for line in f:
    print(line)
print('_'*30)

print('ИЗМЕНЕННЫЙ ФАЙЛ')
print('-'*30)
with open('new', 'rb') as f:
  for line in f:
    print(line)
# Out:
# ИСХОДНЫЙ ФАЙЛ
# ------------------------------
# b'import string\n'
# b'import abc\n'
# b'from collections import defaultdict\n'
# b'\n'
# b'from main.config import ALPHABET_POWER, ALPHABET_LETTER_CODE\n'
# b'from main.encode import CaesarEncoderDecoder\n'
# b'from main.train import DefaultTrainer\n'
# b'\n'
# b'\n'
# b'class Hacker:\n'
# b'    __metaclass__ = abc.ABCMeta\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        self.model = defaultdict(float, model)\n'
# b'\n'
# b'    @abc.abstractmethod\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        pass\n'
# b'\n'
# b'\n'
# b'class CaesarHacker(Hacker):\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        super().__init__(model)\n'
# b'        self.caesar_decoders = [CaesarEncoderDecoder(shift) for shift in range(ALPHABET_POWER)]\n'
# b'        self.trainer = DefaultTrainer()\n'
# b'\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        results = [0 for shift in range(ALPHABET_POWER)]\n'
# b'        shift_result = 0\n'
# b'\n'
# b'        self.trainer.feed(text)\n'
# b'        current_model = self.trainer.get_model()\n'
# b'        for shift in range(ALPHABET_POWER):\n'
# b'            for letter in string.ascii_lowercase:\n'
# b'                results[shift] += (self.model[letter] - current_model[letter]) ** 2\n'
# b'            if results[shift] < results[shift_result]:\n'
# b'                shift_result = shift\n'
# b'\n'
# b'            tmp = current_model[ALPHABET_POWER - 1]\n'
# b'            for letter_id in range(ALPHABET_POWER):\n'
# b'                current_model[string.ascii_lowercase[letter_id]] = current_model[\n'
# b'                    string.ascii_lowercase[(letter_id + 1) % ALPHABET_POWER]]\n'
# b'            current_model[0] = tmp\n'
# b'\n'
# b'        self.trainer.clear()\n'
# b'\n'
# b"        return self.caesar_decoders[shift_result].encode(text, 'decode')\n"
# b'\n'
# b'\n'
# b'class VigenereHacker(Hacker):\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        super().__init__(model)\n'
# b'        try:\n'
# b"            self.coincidence_index = self.model['coincidence_index']\n"
# b'        except KeyError:\n'
# b"            raise KeyError('Wrong model format')\n"
# b'\n'
# b'    def calc_coincidence_index(self, text: str):\n'
# b'        count = [0 for letter in range(ALPHABET_POWER)]\n'
# b'        sum_count = 0\n'
# b'\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b"                count[ALPHABET_LETTER_CODE[letter.lower()] - ALPHABET_LETTER_CODE['a']] += 1\n"
# b'                sum_count += 1\n'
# b'\n'
# b'        if sum_count <= 2:\n'
# b'            return 0\n'
# b'\n'
# b'import string\n'
# b'import abc\n'
# b'from collections import defaultdict\n'
# b'\n'
# b'from main.config import ALPHABET_POWER, ALPHABET_LETTER_CODE\n'
# b'from main.encode import CaesarEncoderDecoder\n'
# b'from main.train import DefaultTrainer\n'
# b'\n'
# b'\n'
# b'class Hacker:\n'
# b'    __metaclass__ = abc.ABCMeta\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        self.model = defaultdict(float, model)\n'
# b'\n'
# b'    @abc.abstractmethod\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        pass\n'
# b'\n'
# b'\n'
# b'class CaesarHacker(Hacker):\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        super().__init__(model)\n'
# b'        self.caesar_decoders = [CaesarEncoderDecoder(shift) for shift in range(ALPHABET_POWER)]\n'
# b'        self.trainer = DefaultTrainer()\n'
# b'\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        results = [0 for shift in range(ALPHABET_POWER)]\n'
# b'        shift_result = 0\n'
# b'\n'
# b'        self.trainer.feed(text)\n'
# b'        current_model = self.trainer.get_model()\n'
# b'        for shift in range(ALPHABET_POWER):\n'
# b'            for letter in string.ascii_lowercase:\n'
# b'                results[shift] += (self.model[letter] - current_model[letter]) ** 2\n'
# b'            if results[shift] < results[shift_result]:\n'
# b'                shift_result = shift\n'
# b'\n'
# b'            tmp = current_model[ALPHABET_POWER - 1]\n'
# b'            for letter_id in range(ALPHABET_POWER):\n'
# b'                current_model[string.ascii_lowercase[letter_id]] = current_model[\n'
# b'                    string.ascii_lowercase[(letter_id + 1) % ALPHABET_POWER]]\n'
# b'            current_model[0] = tmp\n'
# b'\n'
# b'        self.trainer.clear()\n'
# b'\n'
# b"        return self.caesar_decoders[shift_result].encode(text, 'decode')\n"
# b'\n'
# b'\n'
# b'class VigenereHacker(Hacker):\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        super().__init__(model)\n'
# b'        try:\n'
# b"            self.coincidence_index = self.model['coincidence_index']\n"
# b'        except KeyError:\n'
# b"            raise KeyError('Wrong model format')\n"
# b'\n'
# b'    def calc_coincidence_index(self, text: str):\n'
# b'        count = [0 for letter in range(ALPHABET_POWER)]\n'
# b'        sum_count = 0\n'
# b'\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b"                count[ALPHABET_LETTER_CODE[letter.lower()] - ALPHABET_LETTER_CODE['a']] += 1\n"
# b'                sum_count += 1\n'
# b'\n'
# b'        if sum_count <= 2:\n'
# b'            return 0\n'
# b'\n'
# b'        result = 0\n'
# b'        for letter in range(ALPHABET_POWER):\n'
# b'            result += (count[letter] * (count[letter] - 1)) / (sum_count * (sum_count - 1))\n'
# b'\n'
# b'        return result\n'
# b'\n'
# b'    def check_length(self, text: str, length: int):\n'
# b'        current_text = []\n'
# b'        for position in range(0, len(text), length):\n'
# b'            current_text.append(text[position])\n'
# b"        return self.calc_coincidence_index(''.join(current_text))\n"
# b'\n'
# b'    def calc_key_len(self, len_ic: list):\n'
# b'        key_len = 1\n'
# b'        for length, coincidence_index in enumerate(len_ic):\n'
# b'            if self.coincidence_index < coincidence_index:\n'
# b'                key_len = length + 1\n'
# b'                break\n'
# b'            if abs(coincidence_index - self.coincidence_index) < abs(len_ic[key_len - 1] - self.coincidence_index):\n'
# b'                key_len = length + 1\n'
# b'        return key_len\n'
# b'\n'
# b'    def calc_result(self, text: str, key_len: int, strings: list):\n'
# b'        result = []\n'
# b'\n'
# b'        letter_id = 0\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b'                symbol = strings[letter_id % key_len][letter_id // key_len]\n'
# b'                if letter.isupper():\n'
# b'                    symbol = symbol.upper()\n'
# b'                result.append(symbol)\n'
# b'                letter_id += 1\n'
# b'            else:\n'
# b'                result.append(letter)\n'
# b'        return result\n'
# b'\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        letters = []\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b'                letters.append(letter.lower())\n'
# b'\n'
# b"        letter_text = ''.join(letters)\n"
# b'\n'
# b'        len_ic = []\n'
# b'        current_length = 1\n'
# b'        while current_length * current_length < len(letter_text):\n'
# b'            len_ic.append(self.check_length(letter_text, current_length))\n'
# b'            current_length += 1\n'
# b'\n'
# b'        key_len = self.calc_key_len(len_ic)\n'
# b'\n'
# b"        strings = ['' for index in range(key_len)]\n"
# b'        for position, symbol in enumerate(letter_text):\n'
# b"            strings[position % key_len] = ''.join((strings[position % key_len],  symbol))\n"
# b'\n'
# b'        caesar_hacker = CaesarHacker(self.model)\n'
# b'        for index in range(key_len):\n'
# b'            strings[index] = caesar_hacker.hack(strings[index])\n'
# b'\n'
# b'        result = self.calc_result(text, key_len, strings)\n'
# b'\n'
# b"        return ''.join(result)"
# ______________________________
# ИЗМЕНЕННЫЙ ФАЙЛ
# ------------------------------
# b'import string\n'
# b'import abc\n'
# b'from collections import defaultdict\n'
# b'\n'
# b'from main.config import ALPHABET_POWER, ALPHABET_LETTER_CODE\n'
# b'from main.encode import CaesarEncoderDecoder\n'
# b'from main.train import DefaultTrainer\n'
# b'\n'
# b'\n'
# b'class Hacker:\n'
# b'    __metaclass__ = abc.ABCMeta\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        self.model = defaultdict(float, model)\n'
# b'\n'
# b'    @abc.abstractmethod\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        pass\n'
# b'\n'
# b'\n'
# b'class CaesarHacker(Hacker):\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        super().__init__(model)\n'
# b'        self.caesar_decoders = [CaesarEncoderDecoder(shift) for shift in range(ALPHABET_POWER)]\n'
# b'        self.trainer = DefaultTrainer()\n'
# b'\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        results = [0 for shift in range(ALPHABET_POWER)]\n'
# b'        shift_result = 0\n'
# b'\n'
# b'        self.trainer.feed(text)\n'
# b'        current_model = self.trainer.get_model()\n'
# b'        for shift in range(ALPHABET_POWER):\n'
# b'            for letter in string.ascii_lowercase:\n'
# b'                results[shift] += (self.model[letter] - current_model[letter]) ** 2\n'
# b'            if results[shift] < results[shift_result]:\n'
# b'                shift_result = shift\n'
# b'\n'
# b'            tmp = current_model[ALPHABET_POWER - 1]\n'
# b'            for letter_id in range(ALPHABET_POWER):\n'
# b'                current_model[string.ascii_lowercase[letter_id]] = current_model[\n'
# b'                    string.ascii_lowercase[(letter_id + 1) % ALPHABET_POWER]]\n'
# b'            current_model[0] = tmp\n'
# b'\n'
# b'        self.trainer.clear()\n'
# b'\n'
# b"        return self.caesar_decoders[shift_result].encode(text, 'decode')\n"
# b'\n'
# b'\n'
# b'class VigenereHacker(Hacker):\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        super().__init__(model)\n'
# b'        try:\n'
# b"            self.coincidence_index = self.model['coincidence_index']\n"
# b'        except KeyError:\n'
# b"            raise KeyError('Wrong model format')\n"
# b'\n'
# b'    def calc_coincidence_index(self, text: str):\n'
# b'        count = [0 for letter in range(ALPHABET_POWER)]\n'
# b'        sum_count = 0\n'
# b'\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b"                count[ALPHABET_LETTER_CODE[letter.lower()] - ALPHABET_LETTER_CODE['a']] += 1\n"
# b'                sum_count += 1\n'
# b'\n'
# b'        if sum_count <= 2:\n'
# b'            return 0\n'
# b'\n'
# b'import string\n'
# b'import abc\n'
# b'from collections import defaultdict\n'
# b'\n'
# b'from main.config import ALPHABET_POWER, ALPHABET_LETTER_CODE\n'
# b'from main.encode import CaesarEncoderDecoder\n'
# b'from main.train import DefaultTrainer\n'
# b'\n'
# b'\n'
# b'class Hacker:\n'
# b'    __metaclass__ = abc.ABCMeta\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        self.model = defaultdict(float, model)\n'
# b'\n'
# b'    @abc.abstractmethod\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        pass\n'
# b'\n'
# b'\n'
# b'class CaesarHacker(Hacker):\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        super().__init__(model)\n'
# b'        self.caesar_decoders = [CaesarEncoderDecoder(shift) for shift in range(ALPHABET_POWER)]\n'
# b'        self.trainer = DefaultTrainer()\n'
# b'\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        results = [0 for shift in range(ALPHABET_POWER)]\n'
# b'        shift_result = 0\n'
# b'\n'
# b'        self.trainer.feed(text)\n'
# b'        current_model = self.trainer.get_model()\n'
# b'        for shift in range(ALPHABET_POWER):\n'
# b'            for letter in string.ascii_lowercase:\n'
# b'                results[shift] += (self.model[letter] - current_model[letter]) ** 2\n'
# b'            if results[shift] < results[shift_result]:\n'
# b'                shift_result = shift\n'
# b'\n'
# b'            tmp = current_model[ALPHABET_POWER - 1]\n'
# b'            for letter_id in range(ALPHABET_POWER):\n'
# b'                current_model[string.ascii_lowercase[letter_id]] = current_model[\n'
# b'                    string.ascii_lowercase[(letter_id + 1) % ALPHABET_POWER]]\n'
# b'            current_model[0] = tmp\n'
# b'\n'
# b'        self.trainer.clear()\n'
# b'\n'
# b"        return self.caesar_decoders[shift_result].encode(text, 'decode')\n"
# b'\n'
# b'\n'
# b'class VigenereHacker(Hacker):\n'
# b'\n'
# b'    def __init__(self, model):\n'
# b'        super().__init__(model)\n'
# b'        try:\n'
# b"            self.coincidence_index = self.model['coincidence_index']\n"
# b'        except KeyError:\n'
# b"            raise KeyError('Wrong model format')\n"
# b'\n'
# b'    def calc_coincidence_index(self, text: str):\n'
# b'        count = [0 for letter in range(ALPHABET_POWER)]\n'
# b'        sum_count = 0\n'
# b'\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b"                count[ALPHABET_LETTER_CODE[letter.lower()] - ALPHABET_LETTER_CODE['a']] += 1\n"
# b'                sum_count += 1\n'
# b'\n'
# b'        if sum_count <= 2:\n'
# b'            return 0\n'
# b'\n'
# b'        result = 0\n'
# b'        for letter in range(ALPHABET_POWER):\n'
# b'            result += (count[letter] * (count[letter] - 1)) / (sum_count * (sum_count - 1))\n'
# b'\n'
# b'        return result\n'
# b'\n'
# b'    def check_length(self, text: str, length: int):\n'
# b'        current_text = []\n'
# b'        for position in range(0, len(text), length):\n'
# b'            current_text.append(text[position])\n'
# b"        return self.calc_coincidence_index(''.join(current_text))\n"
# b'\n'
# b'    def calc_key_len(self, len_ic: list):\n'
# b'        key_len = 1\n'
# b'        for length, coincidence_index in enumerate(len_ic):\n'
# b'            if self.coincidence_index < coincidence_index:\n'
# b'                key_len = length + 1\n'
# b'                break\n'
# b'            if abs(coincidence_index - self.coincidence_index) < abs(len_ic[key_len - 1] - self.coincidence_index):\n'
# b'                key_len = length + 1\n'
# b'        return key_len\n'
# b'\n'
# b'    def calc_result(self, text: str, key_len: int, strings: list):\n'
# b'        result = []\n'
# b'\n'
# b'        letter_id = 0\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b'                symbol = strings[letter_id % key_len][letter_id // key_len]\n'
# b'                if letter.isupper():\n'
# b'                    symbol = symbol.upper()\n'
# b'                result.append(symbol)\n'
# b'                letter_id += 1\n'
# b'            else:\n'
# b'                result.append(letter)\n'
# b'        return result\n'
# b'\n'
# b'    def hack(self, text: str, subcomm=None):\n'
# b'        letters = []\n'
# b'        for letter in text:\n'
# b'            if letter.isalpha():\n'
# b'                letters.append(letter.lower())\n'
# b'\n'
# b"        letter_text = ''.join(letters)\n"
# b'\n'
# b'        len_ic = []\n'
# b'        current_length = 1\n'
# b'        while current_length * current_length < len(letter_text):\n'
# b'            len_ic.append(self.check_length(letter_text, current_length))\n'
# b'            current_length += 1\n'
# b'\n'
# b'        key_len = self.calc_key_len(len_ic)\n'
# b'\n'
# b"        strings = ['' for index in range(key_len)]\n"
# b'        for position, symbol in enumerate(letter_text):\n'
# b"            strings[position % key_len] = ''.join((strings[position % key_len],  symbol))\n"
# b'\n'
# b'        caesar_hacker = CaesarHacker(self.model)\n'
# b'        for index in range(key_len):\n'
# b'            strings[index] = caesar_hacker.hack(strings[index])\n'
# b'\n'
# b'        result = self.calc_result(text, key_len, strings)\n'
# b'\n'
# b"        return ''.join(result)"

# %% [markdown]
# Что бы я добавил:
#
# Можно обернуть все в класс, чтобы защитить приватные методы и внутренний класс.
# Поменял бы класс для диф_строк и оптимизировал алгоритм.
#
# Почистил код стайл :)
